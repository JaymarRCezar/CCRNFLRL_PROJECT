# %% [markdown]
# # Deep Q learning with Doom 🕹️
# In this notebook we'll implement an agent <b>that plays Doom by using a Deep Q learning architecture.</b> <br>
# Our agent playing Doom:
#
#
#
# <img src="assets/doom.gif" style="max-width: 600px;" alt="Deep Q learning with Doom"/>

# %% [markdown]
# ## For Google Collab

# %%
# %%bash
# # Install deps from
# # https://github.com/mwydmuch/ViZDoom/blob/master/doc/Building.md#-linux
#
# apt-get install build-essential zlib1g-dev libsdl2-dev libjpeg-dev \
# nasm tar libbz2-dev libgtk2.0-dev cmake git libfluidsynth-dev libgme-dev \
# libopenal-dev timidity libwildmidi-dev unzip
#
# # Boost libraries
# apt-get install libboost-all-dev
#
# # Lua binding dependencies
# apt-get install liblua5.1-dev
# Out:
# Couldn't find program: 'bash'

# %% [markdown]
# ## Install vizdoom, tensorflow and scikit-image

# %%
# !pip install vizdoom
# !pip install tensorflow
# !pip install scikit-image
# Out:
# Requirement already satisfied: vizdoom in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (1.2.0)
# Requirement already satisfied: numpy in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from vizdoom) (1.23.5)
# Requirement already satisfied: gymnasium>=0.28.0 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from vizdoom) (0.28.1)
# Requirement already satisfied: pygame>=2.1.3 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from vizdoom) (2.4.0)
# Requirement already satisfied: jax-jumpy>=1.0.0 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from gymnasium>=0.28.0->vizdoom) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from gymnasium>=0.28.0->vizdoom) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from gymnasium>=0.28.0->vizdoom) (4.6.3)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from gymnasium>=0.28.0->vizdoom) (0.0.4)
# Requirement already satisfied: tensorflow in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (2.12.0)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.12)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (16.0.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\jaymar cezar\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.23.3)
# Requirement already satisfied: setuptools in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\jaymar cezar\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.6.3)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.54.2)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.1.0 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: scipy>=1.7 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.10.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.20.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.3.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (4.9)
# Requirement already satisfied: urllib3<2.0 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.16)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.2.2)
# Requirement already satisfied: scikit-image in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (0.21.0)
# Requirement already satisfied: numpy>=1.21.1 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from scikit-image) (1.23.5)
# Requirement already satisfied: scipy>=1.8 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from scikit-image) (1.10.0)
# Requirement already satisfied: networkx>=2.8 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from scikit-image) (3.1)
# Requirement already satisfied: pillow>=9.0.1 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from scikit-image) (9.4.0)
# Requirement already satisfied: imageio>=2.27 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from scikit-image) (2.31.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from scikit-image) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from scikit-image) (1.4.1)
# Requirement already satisfied: packaging>=21 in c:\users\jaymar cezar\appdata\roaming\python\python311\site-packages (from scikit-image) (23.0)
# Requirement already satisfied: lazy_loader>=0.2 in c:\users\jaymar cezar\appdata\local\programs\python\python311\lib\site-packages (from scikit-image) (0.2)

# %% [markdown]
# ## Step 1: Import the libraries 📚

# %%
import tensorflow as tf      # Deep Learning library
import numpy as np           # Handle matrices
from vizdoom import *        # Doom Environment

import random                # Handling random number generation
import time                  # Handling time calculation
from skimage import transform# Help us to preprocess the frames

from collections import deque# Ordered collection with ends
import matplotlib.pyplot as plt # Display graphs

import warnings # This ignore all the warning messages that are normally printed during the training because of skiimage
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Step 2: Create our environment 🎮
# - Now that we imported the libraries/dependencies, we will create our environment.
# - Doom environment takes:
#     - A `configuration file` that **handle all the options** (size of the frame, possible actions...)
#     - A `scenario file`: that **generates the correct scenario** (in our case basic **but you're invited to try other scenarios**).
# - Note: We have 3 possible actions `[[0,0,1], [1,0,0], [0,1,0]]` so we don't need to do one hot encoding (thanks to < a href="https://stackoverflow.com/users/2237916/silgon">silgon</a> for figuring out.
#
# ### Our environment
# <img src="assets/doom.png" style="max-width:500px;" alt="Doom"/>
#
# - A monster is spawned **randomly somewhere along the opposite wall**.
# - Player can only go **left/right and shoot**.
# - 1 hit is enough **to kill the monster**.
# - Episode finishes when **monster is killed or on timeout (300)**.
# <br><br>
# REWARDS:
#
# - +101 for killing the monster
# - -5 for missing
# - Episode ends after killing the monster or on timeout.
# - living reward = -1

# %%
"""
Here we create our environment
"""
def create_environment():
    game = DoomGame()

    # Load the correct configuration
    game.load_config("basic.cfg")

    # Load the correct scenario (in our case basic scenario)
    game.set_doom_scenario_path("basic.wad")

    # For Google Collab
    #game.set_window_visible(False)

    game.init()

    # Here our possible actions
    left = [1, 0, 0]
    right = [0, 1, 0]
    shoot = [0, 0, 1]
    possible_actions = [left, right, shoot]

    return game, possible_actions

"""
Here we performing random action to test the environment
"""
def test_environment():
    game = DoomGame()
    game.load_config("basic.cfg")
    game.set_doom_scenario_path("basic.wad")
    game.init()
    shoot = [0, 0, 1]
    left = [1, 0, 0]
    right = [0, 1, 0]
    actions = [shoot, left, right]

    episodes = 10
    for i in range(episodes):
        game.new_episode()
        while not game.is_episode_finished():
            state = game.get_state()
            img = state.screen_buffer
            misc = state.game_variables
            action = random.choice(actions)
            print(action)
            reward = game.make_action(action)
            print ("\treward:", reward)
            time.sleep(0.02)
        print ("Result:", game.get_total_reward())
        time.sleep(2)
    game.close()

# %%
game, possible_actions = create_environment()

# %% [markdown]
# ## Step 3: Define the preprocessing functions ⚙️
# ### preprocess_frame
# Preprocessing is an important step, <b>because we want to reduce the complexity of our states to reduce the computation time needed for training.</b>
# <br><br>
# Our steps:
# - Grayscale each of our frames (because <b> color does not add important information </b>). But this is already done by the config file.
# - Crop the screen (in our case we remove the roof because it contains no information)
# - We normalize pixel values
# - Finally we resize the preprocessed frame

# %%
"""
    preprocess_frame:
    Take a frame.
    Resize it.
        __________________
        |                 |
        |                 |
        |                 |
        |                 |
        |_________________|

        to
        _____________
        |            |
        |            |
        |            |
        |____________|
    Normalize it.

    return preprocessed_frame

    """
def preprocess_frame(frame):
    # Greyscale frame already done in our vizdoom config
    # x = np.mean(frame,-1)

    # Crop the screen (remove the roof because it contains no information)
    cropped_frame = frame[30:-10,30:-30]

    # Normalize Pixel Values
    normalized_frame = cropped_frame/255.0

    # Resize
    preprocessed_frame = transform.resize(normalized_frame, [90,90])

    return preprocessed_frame

# %% [markdown]
# ### stack_frames
# 👏 This part was made possible thanks to help of <a href="https://github.com/Miffyli">Anssi</a><br>
#
# As explained in this really <a href="https://danieltakeshi.github.io/2016/11/25/frame-skipping-and-preprocessing-for-deep-q-networks-on-atari-2600-games/">  good article </a> we stack frames.
#
# Stacking frames is really important because it helps us to **give have a sense of motion to our Neural Network.**
#
# - First we preprocess frame
# - Then we append the frame to the deque that automatically **removes the oldest frame**
# - Finally we **build the stacked state**
#
# This is how work stack:
# - For the first frame, we feed 4 frames
# - At each timestep, **we add the new frame to deque and then we stack them to form a new stacked frame**
# - And so on
# <img src="https://raw.githubusercontent.com/simoninithomas/Deep_reinforcement_learning_Course/master/DQN/Space%20Invaders/assets/stack_frames.png" alt="stack">
# - If we're done, **we create a new stack with 4 new frames (because we are in a new episode)**.

# %%
stack_size = 4 # We stack 4 frames

# Initialize deque with zero-images one array for each image
stacked_frames  =  deque([np.zeros((90,90), dtype=np.int) for i in range(stack_size)], maxlen=4)

def stack_frames(stacked_frames, state, is_new_episode):
    # Preprocess frame
    frame = preprocess_frame(state)

    if is_new_episode:
        # Clear our stacked_frames
        stacked_frames = deque([np.zeros((84,84), dtype=np.int) for i in range(stack_size)], maxlen=4)

        # Because we're in a new episode, copy the same frame 4x
        stacked_frames.append(frame)
        stacked_frames.append(frame)
        stacked_frames.append(frame)
        stacked_frames.append(frame)

        # Stack the frames
        stacked_state = np.stack(stacked_frames, axis=2)

    else:
        # Append frame to deque, automatically removes the oldest frame
        stacked_frames.append(frame)

        # Build the stacked state (first dimension specifies different frames)
        stacked_state = np.stack(stacked_frames, axis=2)

    return stacked_state, stacked_frames

# %% [markdown]
# ## Step 4: Set up our hyperparameters ⚗️
# In this part we'll set up our different hyperparameters. But when you implement a Neural Network by yourself you will **not implement hyperparamaters at once but progressively**.
#
# - First, you begin by defining the neural networks hyperparameters when you implement the model.
# - Then, you'll add the training hyperparameters when you implement the training algorithm.

# %%
### MODEL HYPERPARAMETERS
state_size = [90,90,4]      # Our input is a stack of 4 frames hence 84x84x4 (Width, height, channels)
action_size = game.get_available_buttons_size()              # 3 possible actions: left, right, shoot
learning_rate =  0.0006      # Alpha (aka learning rate)

### TRAINING HYPERPARAMETERS
total_episodes = 600        # Total episodes for training
max_steps = 80              # Max possible steps in an episode
batch_size = 128

# Exploration parameters for epsilon greedy strategy
explore_start = 1.0            # exploration probability at start
explore_stop = 0.01            # minimum exploration probability
decay_rate = 0.0005            # exponential decay rate for exploration prob

# Q learning hyperparameters
gamma = 0.99              # Discounting rate

### MEMORY HYPERPARAMETERS
pretrain_length = batch_size   # Number of experiences stored in the Memory when initialized for the first time
memory_size = 1000000          # Number of experiences the Memory can keep

### MODIFY THIS TO FALSE IF YOU JUST WANT TO SEE THE TRAINED AGENT
training = True

## TURN THIS TO TRUE IF YOU WANT TO RENDER THE ENVIRONMENT
episode_render = False

# %% [markdown]
# ## Step 5: Create our Deep Q-learning Neural Network model 🧠
# <img src="assets/model.png" alt="Model" />
# This is our Deep Q-learning model:
# - We take a stack of 4 frames as input
# - It passes through 3 convnets
# - Then it is flatened
# - Finally it passes through 2 FC layers
# - It outputs a Q value for each actions

# %%
class DQNetwork:
    def __init__(self, state_size, action_size, learning_rate, name='DQNetwork'):
        self.state_size = state_size
        self.action_size = action_size
        self.learning_rate = learning_rate

        with tf.compat.v1.variable_scope(name):
            # We create the placeholders
            # *state_size means that we take each elements of state_size in tuple hence is like if we wrote
            # [None, 84, 84, 4]
            self.inputs_ = tf.compat.v1.placeholder(tf.float32, [None, *state_size], name="inputs")
            self.actions_ = tf.compat.v1.placeholder(tf.float32, [None, 3], name="actions_")

            # Remember that target_Q is the R(s,a) + ymax Qhat(s', a')
            self.target_Q = tf.compat.v1.placeholder(tf.float32, [None], name="target")

            """
            First convnet:
            CNN
            BatchNormalization
            ELU
            """
            # Input is 84x84x4
            self.conv1 = tf.compat.v1.layers.conv2d(inputs = self.inputs_,
                                         filters = 32,
                                         kernel_size = [5,5],
                                         strides = [4,4],
                                         padding = "VALID",
                                          kernel_initializer=tf.compat.v1.keras.initializers.VarianceScaling(scale=1.0, mode="fan_avg", distribution="uniform"),
                                         name = "conv1")

            self.conv1_batchnorm = tf.compat.v1.layers.batch_normalization(self.conv1,
                                                   training = True,
                                                   epsilon = 1e-5,
                                                     name = 'batch_norm1')

            self.conv1_out = tf.nn.elu(self.conv1_batchnorm, name="conv1_out")



            """
            Second convnet:
            CNN
            BatchNormalization
            ELU
            """
            self.conv2 = tf.compat.v1.layers.conv2d(inputs = self.conv1_out,
                                 filters = 64,
                                 kernel_size = [5,5],
                                 strides = [2,2],
                                 padding = "VALID",
                                kernel_initializer=tf.compat.v1.keras.initializers.VarianceScaling(scale=1.0, mode="fan_avg", distribution="uniform"),
                                 name = "conv2")

            self.conv2_batchnorm = tf.compat.v1.layers.batch_normalization(self.conv2,
                                        training = True,
                                        epsilon = 1e-5,
                                          name = 'batch_norm2')


            self.conv2_out = tf.nn.elu(self.conv2_batchnorm, name="conv2_out")
            ## --> [9, 9, 64]


            """
            Third convnet:
            CNN
            BatchNormalization
            ELU
            """
            self.conv3 = tf.compat.v1.layers.conv2d(inputs = self.conv2_out,
                                 filters = 128,
                                 kernel_size = [3,3],
                                 strides = [2,2],
                                 padding = "VALID",
                                kernel_initializer=tf.compat.v1.keras.initializers.VarianceScaling(scale=1.0, mode="fan_avg", distribution="uniform"),
                                 name = "conv3")

            self.conv3_batchnorm = tf.compat.v1.layers.batch_normalization(self.conv3,
                                                   training = True,
                                                   epsilon = 1e-5,
                                                     name = 'batch_norm3')

            self.conv3_out = tf.nn.elu(self.conv3_batchnorm, name="conv3_out")
            ## --> [3, 3, 128]


            self.flatten = tf.compat.v1.layers.flatten(self.conv3_out)
            ## --> [1152]


            self.fc = tf.compat.v1.layers.dense(inputs = self.flatten,
                                  units = 256,
                                  activation = tf.nn.elu,
                                       kernel_initializer=tf.compat.v1.keras.initializers.VarianceScaling(scale=1.0, mode="fan_avg", distribution="uniform"),
                                name="fc1")


            self.output = tf.compat.v1.layers.dense(inputs = self.fc,
                                           kernel_initializer=tf.compat.v1.keras.initializers.VarianceScaling(scale=1.0, mode="fan_avg", distribution="uniform"),
                                          units = 3,
                                        activation=None)


            # Q is our predicted Q value.
            self.Q = tf.reduce_sum(tf.multiply(self.output, self.actions_), axis=1)


            # The loss is the difference between our predicted Q_values and the Q_target
            # Sum(Qtarget - Q)^2
            self.loss = tf.reduce_mean(tf.square(self.target_Q - self.Q))

            self.optimizer = tf.compat.v1.train.RMSPropOptimizer(self.learning_rate).minimize(self.loss)

# %%
tf.compat.v1.disable_eager_execution()

# %%
# Reset the graph
tf.compat.v1.reset_default_graph()

# Instantiate the DQNetwork
DQNetwork = DQNetwork(state_size, action_size, learning_rate)
# Out:
# WARNING:tensorflow:From c:\Users\Jaymar Cezar\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\layers\normalization\batch_normalization.py:581: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From c:\Users\Jaymar Cezar\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\training\rmsprop.py:188: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
print(DQNetwork.conv1)
print(DQNetwork.conv2)
print(DQNetwork.conv3)

print(DQNetwork.flatten)
print(DQNetwork.fc)
# Out:
# Tensor("DQNetwork/conv1/BiasAdd:0", shape=(None, 22, 22, 32), dtype=float32)
# Tensor("DQNetwork/conv2/BiasAdd:0", shape=(None, 9, 9, 64), dtype=float32)
# Tensor("DQNetwork/conv3/BiasAdd:0", shape=(None, 4, 4, 128), dtype=float32)
# Tensor("DQNetwork/flatten/Reshape:0", shape=(None, 2048), dtype=float32)
# Tensor("DQNetwork/fc1/Elu:0", shape=(None, 256), dtype=float32)

# %% [markdown]
# ## Step 6: Experience Replay 🔁
# Now that we create our Neural Network, **we need to implement the Experience Replay method.** <br><br>
# Here we'll create the Memory object that creates a deque.A deque (double ended queue) is a data type that **removes the oldest element each time that you add a new element.**
#
# This part was taken from Udacity : <a href="https://github.com/udacity/deep-learning/blob/master/reinforcement/Q-learning-cart.ipynb" Cartpole DQN</a>

# %%
class Memory():
    def __init__(self, max_size):
        self.buffer = deque(maxlen = max_size)

    def add(self, experience):
        self.buffer.append(experience)

    def sample(self, batch_size):
        buffer_size = len(self.buffer)
        index = np.random.choice(np.arange(buffer_size),
                                size = batch_size,
                                replace = False)

        return [self.buffer[i] for i in index]

# %% [markdown]
# Here we'll **deal with the empty memory problem**: we pre-populate our memory by taking random actions and storing the experience (state, action, reward, new_state).

# %%
# Instantiate memory
memory = Memory(max_size = memory_size)

# Render the environment
game.new_episode()

for i in range(pretrain_length):
    # If it's the first step
    if i == 0:
        # First we need a state
        state = game.get_state().screen_buffer
        state, stacked_frames = stack_frames(stacked_frames, state, True)

    # Random action
    action = random.choice(possible_actions)

    # Get the rewards
    reward = game.make_action(action)

    # Look if the episode is finished
    done = game.is_episode_finished()

    # If we're dead
    if done:
        # We finished the episode
        next_state = np.zeros(state.shape)

        # Add experience to memory
        memory.add((state, action, reward, next_state, done))

        # Start a new episode
        game.new_episode()

        # First we need a state
        state = game.get_state().screen_buffer

        # Stack the frames
        state, stacked_frames = stack_frames(stacked_frames, state, True)

    else:
        # Get the next state
        next_state = game.get_state().screen_buffer
        next_state, stacked_frames = stack_frames(stacked_frames, next_state, False)

        # Add experience to memory
        memory.add((state, action, reward, next_state, done))

        # Our state is now the next_state
        state = next_state

# %% [markdown]
# ## Step 7: Set up Tensorboard 📊
# For more information about tensorboard, please watch this <a href="https://www.youtube.com/embed/eBbEDRsCmv4">excellent 30min tutorial</a> <br><br>
# To launch tensorboard : `tensorboard --logdir=/tensorboard/dqn/1`

# %%
# Setup TensorBoard Writer
writer = tf.compat.v1.summary.FileWriter("/tensorboard/dqn/1")

## Losses
tf.compat.v1.summary.scalar("Loss", DQNetwork.loss)

write_op = tf.compat.v1.summary.merge_all()

# %% [markdown]
# ## Step 8: Train our Agent 🏃‍♂️
#
# Our algorithm:
# <br>
# * Initialize the weights
# * Init the environment
# * Initialize the decay rate (that will use to reduce epsilon)
# <br><br>
# * **For** episode to max_episode **do**
#     * Make new episode
#     * Set step to 0
#     * Observe the first state $s_0$
#     <br><br>
#     * **While** step < max_steps **do**:
#         * Increase decay_rate
#         * With $\epsilon$ select a random action $a_t$, otherwise select $a_t = \mathrm{argmax}_a Q(s_t,a)$
#         * Execute action $a_t$ in simulator and observe reward $r_{t+1}$ and new state $s_{t+1}$
#         * Store transition $<s_t, a_t, r_{t+1}, s_{t+1}>$ in memory $D$
#         * Sample random mini-batch from $D$: $<s, a, r, s'>$
#         * Set $\hat{Q} = r$ if the episode ends at $+1$, otherwise set $\hat{Q} = r + \gamma \max_{a'}{Q(s', a')}$
#         * Make a gradient descent step with loss $(\hat{Q} - Q(s, a))^2$
#     * **endfor**
#     <br><br>
# * **endfor**

# %%
"""
This function will do the part
With Ïµ select a random action atat, otherwise select at=argmaxaQ(st,a)
"""
def predict_action(explore_start, explore_stop, decay_rate, decay_step, state, actions):
    ## EPSILON GREEDY STRATEGY
    # Choose action a from state s using epsilon greedy.
    ## First we randomize a number
    exp_exp_tradeoff = np.random.rand()

    # Here we'll use an improved version of our epsilon greedy strategy used in Q-learning notebook
    explore_probability = explore_stop + (explore_start - explore_stop) * np.exp(-decay_rate * decay_step)

    if (explore_probability > exp_exp_tradeoff):
        # Make a random action (exploration)
        action = random.choice(possible_actions)

    else:
        # Get action from Q-network (exploitation)
        # Estimate the Qs values state
        Qs = sess.run(DQNetwork.output, feed_dict = {DQNetwork.inputs_: state.reshape((1, *state.shape))})

        # Take the biggest Q value (= the best action)
        choice = np.argmax(Qs)
        action = possible_actions[int(choice)]

    return action, explore_probability

# %%
# Saver will help us to save our model
saver = tf.compat.v1.train.Saver()

if training == True:
    with tf.compat.v1.Session() as sess:
        # Initialize the variables
        sess.run(tf.compat.v1.global_variables_initializer())

        # Initialize the decay rate (that will use to reduce epsilon)
        decay_step = 0

        # Init the game
        game.init()

        for episode in range(total_episodes):
            # Set step to 0
            step = 0

            # Initialize the rewards of the episode
            episode_rewards = []

            # Make a new episode and observe the first state
            game.new_episode()
            state = game.get_state().screen_buffer

            # Remember that stack frame function also call our preprocess function.
            state, stacked_frames = stack_frames(stacked_frames, state, True)

            while step < max_steps:
                step += 1

                # Increase decay_step
                decay_step +=1

                # Predict the action to take and take it
                action, explore_probability = predict_action(explore_start, explore_stop, decay_rate, decay_step, state, possible_actions)

                # Do the action
                reward = game.make_action(action)

                # Look if the episode is finished
                done = game.is_episode_finished()

                # Add the reward to total reward
                episode_rewards.append(reward)

                # If the game is finished
                if done:
                    # the episode ends so no next state
                    next_state = np.zeros((90,90), dtype=np.int)
                    next_state, stacked_frames = stack_frames(stacked_frames, next_state, False)

                    # Set step = max_steps to end the episode
                    step = max_steps

                    # Get the total reward of the episode
                    total_reward = np.sum(episode_rewards)

                    print('Episode: {}'.format(episode),
                              'Total reward: {}'.format(total_reward),
                              'Training loss: {:.4f}'.format(loss),
                              'Explore P: {:.4f}'.format(explore_probability))

                    memory.add((state, action, reward, next_state, done))

                else:
                    # Get the next state
                    next_state = game.get_state().screen_buffer

                    # Stack the frame of the next_state
                    next_state, stacked_frames = stack_frames(stacked_frames, next_state, False)


                    # Add experience to memory
                    memory.add((state, action, reward, next_state, done))

                    # st+1 is now our current state
                    state = next_state


                ### LEARNING PART
                # Obtain random mini-batch from memory
                batch = memory.sample(batch_size)
                states_mb = np.array([each[0] for each in batch], ndmin=3)
                actions_mb = np.array([each[1] for each in batch])
                rewards_mb = np.array([each[2] for each in batch])
                next_states_mb = np.array([each[3] for each in batch], ndmin=3)
                dones_mb = np.array([each[4] for each in batch])

                target_Qs_batch = []

                 # Get Q values for next_state
                Qs_next_state = sess.run(DQNetwork.output, feed_dict = {DQNetwork.inputs_: next_states_mb})

                # Set Q_target = r if the episode ends at s+1, otherwise set Q_target = r + gamma*maxQ(s', a')
                for i in range(0, len(batch)):
                    terminal = dones_mb[i]

                    # If we are in a terminal state, only equals reward
                    if terminal:
                        target_Qs_batch.append(rewards_mb[i])

                    else:
                        target = rewards_mb[i] + gamma * np.max(Qs_next_state[i])
                        target_Qs_batch.append(target)


                targets_mb = np.array([each for each in target_Qs_batch])

                loss, _ = sess.run([DQNetwork.loss, DQNetwork.optimizer],
                                    feed_dict={DQNetwork.inputs_: states_mb,
                                               DQNetwork.target_Q: targets_mb,
                                               DQNetwork.actions_: actions_mb})

                # Write TF Summaries
                summary = sess.run(write_op, feed_dict={DQNetwork.inputs_: states_mb,
                                                   DQNetwork.target_Q: targets_mb,
                                                   DQNetwork.actions_: actions_mb})
                writer.add_summary(summary, episode)
                writer.flush()

            # Save model every 5 episodes
            if episode % 5 == 0:
                save_path = saver.save(sess, "./models/model.ckpt")
                print("Model Saved")
# Out:
# Episode: 0 Total reward: 92.0 Training loss: 8.6200 Explore P: 0.9956
# Model Saved
# Episode: 1 Total reward: 95.0 Training loss: 206.1180 Explore P: 0.9926
# Episode: 2 Total reward: 95.0 Training loss: 210.8030 Explore P: 0.9897
# Episode: 3 Total reward: 95.0 Training loss: 202.7993 Explore P: 0.9867
# Episode: 4 Total reward: 90.0 Training loss: 61.5451 Explore P: 0.9814
# Model Saved
# Episode: 6 Total reward: 95.0 Training loss: 12.9718 Explore P: 0.9405
# Episode: 10 Total reward: 92.0 Training loss: 7.0612 Explore P: 0.8316
# Model Saved
# Episode: 11 Total reward: 95.0 Training loss: 8.2129 Explore P: 0.8291
# Episode: 12 Total reward: 94.0 Training loss: 4.5041 Explore P: 0.8262
# Episode: 13 Total reward: 93.0 Training loss: 7.8548 Explore P: 0.8230
# Episode: 14 Total reward: 95.0 Training loss: 46.0789 Explore P: 0.8205
# Episode: 15 Total reward: 95.0 Training loss: 93.4993 Explore P: 0.8181
# Model Saved
# Episode: 17 Total reward: 95.0 Training loss: 6.0735 Explore P: 0.7841
# Episode: 20 Total reward: 91.0 Training loss: 4.7951 Explore P: 0.7210
# Model Saved
# Episode: 21 Total reward: 95.0 Training loss: 17.9541 Explore P: 0.7189
# Episode: 22 Total reward: 92.0 Training loss: 16.2984 Explore P: 0.7157
# Episode: 23 Total reward: 49.0 Training loss: 5.3972 Explore P: 0.7010
# Model Saved
# Episode: 27 Total reward: 40.0 Training loss: 6.6701 Explore P: 0.6075
# Episode: 29 Total reward: 95.0 Training loss: 6.6123 Explore P: 0.5823
# Episode: 30 Total reward: 93.0 Training loss: 7.5465 Explore P: 0.5800
# Model Saved
# Episode: 31 Total reward: 90.0 Training loss: 8.3088 Explore P: 0.5769
# Episode: 32 Total reward: 93.0 Training loss: 4.8351 Explore P: 0.5746
# Episode: 33 Total reward: 93.0 Training loss: 4.7167 Explore P: 0.5724
# Episode: 34 Total reward: 95.0 Training loss: 7.7526 Explore P: 0.5707
# Episode: 35 Total reward: 24.0 Training loss: 10.2484 Explore P: 0.5536
# Model Saved
# Episode: 37 Total reward: 94.0 Training loss: 7.9365 Explore P: 0.5305
# Episode: 38 Total reward: 69.0 Training loss: 8.1201 Explore P: 0.5235
# Episode: 39 Total reward: 38.0 Training loss: 13.2029 Explore P: 0.5100
# Episode: 40 Total reward: 95.0 Training loss: 10.1043 Explore P: 0.5086
# Model Saved
# Episode: 41 Total reward: 71.0 Training loss: 22.5005 Explore P: 0.5024
# Episode: 42 Total reward: 69.0 Training loss: 20.9501 Explore P: 0.4958
# Episode: 45 Total reward: 38.0 Training loss: 28.6897 Explore P: 0.4467
# Model Saved
# Episode: 46 Total reward: 95.0 Training loss: 10.7750 Explore P: 0.4454
# Episode: 47 Total reward: 94.0 Training loss: 8.7042 Explore P: 0.4439
# Episode: 48 Total reward: 53.0 Training loss: 30.6476 Explore P: 0.4357
# Episode: 49 Total reward: 94.0 Training loss: 27.3328 Explore P: 0.4342
# Episode: 50 Total reward: 95.0 Training loss: 76.1091 Explore P: 0.4329
# Model Saved
# Episode: 51 Total reward: 95.0 Training loss: 15.8494 Explore P: 0.4317
# Episode: 52 Total reward: 55.0 Training loss: 11.3475 Explore P: 0.4231
# Episode: 53 Total reward: 92.0 Training loss: 9.7154 Explore P: 0.4213
# Episode: 54 Total reward: 69.0 Training loss: 33.3095 Explore P: 0.4157
# Episode: 55 Total reward: 70.0 Training loss: 12.8434 Explore P: 0.4105
# Model Saved
# Episode: 56 Total reward: 94.0 Training loss: 15.4242 Explore P: 0.4091
# Episode: 57 Total reward: 91.0 Training loss: 6.9529 Explore P: 0.4071
# Episode: 58 Total reward: 70.0 Training loss: 8.0976 Explore P: 0.4020
# Episode: 59 Total reward: 90.0 Training loss: 10.1540 Explore P: 0.3998
# Episode: 60 Total reward: 92.0 Training loss: 11.2444 Explore P: 0.3981
# Model Saved
# Episode: 61 Total reward: 51.0 Training loss: 7.0998 Explore P: 0.3904
# Episode: 62 Total reward: 95.0 Training loss: 9.5553 Explore P: 0.3893
# Episode: 63 Total reward: 31.0 Training loss: 12.8828 Explore P: 0.3790
# Episode: 64 Total reward: 68.0 Training loss: 8.1204 Explore P: 0.3738
# Episode: 65 Total reward: 92.0 Training loss: 6.6065 Explore P: 0.3722
# Model Saved
# Episode: 66 Total reward: 95.0 Training loss: 8.0018 Explore P: 0.3711
# Episode: 67 Total reward: 76.0 Training loss: 7.6200 Explore P: 0.3675
# Episode: 68 Total reward: 95.0 Training loss: 10.3565 Explore P: 0.3665
# Episode: 69 Total reward: 94.0 Training loss: 7.7504 Explore P: 0.3652
# Episode: 70 Total reward: 91.0 Training loss: 25.0607 Explore P: 0.3634
# Model Saved
# Episode: 71 Total reward: 95.0 Training loss: 5.1949 Explore P: 0.3624
# Episode: 72 Total reward: 95.0 Training loss: 13.1431 Explore P: 0.3613
# Episode: 73 Total reward: 92.0 Training loss: 15.2116 Explore P: 0.3597
# Episode: 74 Total reward: 95.0 Training loss: 23.3250 Explore P: 0.3587
# Model Saved
# Episode: 76 Total reward: 89.0 Training loss: 6.1595 Explore P: 0.3430
# Episode: 77 Total reward: 95.0 Training loss: 10.9704 Explore P: 0.3420
# Episode: 78 Total reward: 95.0 Training loss: 4.9773 Explore P: 0.3410
# Model Saved
# Episode: 81 Total reward: 94.0 Training loss: 5.3081 Explore P: 0.3145
# Episode: 82 Total reward: 95.0 Training loss: 8.3538 Explore P: 0.3136
# Episode: 83 Total reward: 95.0 Training loss: 8.9906 Explore P: 0.3127
# Episode: 84 Total reward: 95.0 Training loss: 6.5870 Explore P: 0.3118
# Episode: 85 Total reward: 94.0 Training loss: 4.6337 Explore P: 0.3107
# Model Saved
# Episode: 86 Total reward: 94.0 Training loss: 8.4107 Explore P: 0.3097
# Episode: 87 Total reward: 93.0 Training loss: 6.4052 Explore P: 0.3085
# Episode: 88 Total reward: 95.0 Training loss: 5.8293 Explore P: 0.3076
# Episode: 89 Total reward: 95.0 Training loss: 4.6194 Explore P: 0.3067
# Episode: 90 Total reward: 94.0 Training loss: 6.6184 Explore P: 0.3057
# Model Saved
# Episode: 92 Total reward: 95.0 Training loss: 6.4974 Explore P: 0.2932
# Episode: 94 Total reward: 75.0 Training loss: 6.1414 Explore P: 0.2793
# Model Saved
# Episode: 96 Total reward: 95.0 Training loss: 6.3038 Explore P: 0.2679
# Episode: 97 Total reward: 93.0 Training loss: 4.6538 Explore P: 0.2669
# Episode: 98 Total reward: 94.0 Training loss: 5.4196 Explore P: 0.2660
# Episode: 99 Total reward: 95.0 Training loss: 6.1514 Explore P: 0.2652
# Episode: 100 Total reward: 95.0 Training loss: 7.1058 Explore P: 0.2645
# Model Saved
# Episode: 101 Total reward: 91.0 Training loss: 4.2585 Explore P: 0.2632
# Episode: 102 Total reward: 92.0 Training loss: 8.4096 Explore P: 0.2621
# Episode: 103 Total reward: 95.0 Training loss: 7.8785 Explore P: 0.2613
# Episode: 104 Total reward: 95.0 Training loss: 6.8681 Explore P: 0.2606
# Episode: 105 Total reward: 94.0 Training loss: 5.4229 Explore P: 0.2597
# Model Saved
# Episode: 106 Total reward: 38.0 Training loss: 6.3510 Explore P: 0.2532
# Episode: 107 Total reward: 59.0 Training loss: 7.2974 Explore P: 0.2487
# Episode: 108 Total reward: 94.0 Training loss: 5.3535 Explore P: 0.2479
# Episode: 109 Total reward: 17.0 Training loss: 9.7412 Explore P: 0.2398
# Episode: 110 Total reward: 76.0 Training loss: 10.5543 Explore P: 0.2375
# Model Saved
# Episode: 111 Total reward: 95.0 Training loss: 7.2919 Explore P: 0.2368
# Episode: 112 Total reward: 50.0 Training loss: 4.8033 Explore P: 0.2322
# Episode: 113 Total reward: 95.0 Training loss: 6.0483 Explore P: 0.2316
# Episode: 114 Total reward: 95.0 Training loss: 5.4696 Explore P: 0.2309
# Episode: 115 Total reward: 94.0 Training loss: 6.9756 Explore P: 0.2301
# Model Saved
# Episode: 117 Total reward: 56.0 Training loss: 11.4487 Explore P: 0.2178
# Episode: 118 Total reward: 93.0 Training loss: 7.7692 Explore P: 0.2170
# Episode: 119 Total reward: 93.0 Training loss: 7.7451 Explore P: 0.2162
# Episode: 120 Total reward: 95.0 Training loss: 7.8516 Explore P: 0.2156
# Model Saved
# Episode: 121 Total reward: 11.0 Training loss: 5.2329 Explore P: 0.2080
# Episode: 122 Total reward: 95.0 Training loss: 4.1130 Explore P: 0.2074
# Episode: 123 Total reward: 95.0 Training loss: 6.0805 Explore P: 0.2068
# Episode: 124 Total reward: 95.0 Training loss: 7.0415 Explore P: 0.2062
# Episode: 125 Total reward: 51.0 Training loss: 6.6750 Explore P: 0.2023
# Model Saved
# Episode: 126 Total reward: 34.0 Training loss: 9.3100 Explore P: 0.1969
# Episode: 128 Total reward: 39.0 Training loss: 6.6035 Explore P: 0.1850
# Episode: 129 Total reward: 95.0 Training loss: 8.8779 Explore P: 0.1845
# Episode: 130 Total reward: 95.0 Training loss: 8.1081 Explore P: 0.1839
# Model Saved
# Episode: 131 Total reward: 92.0 Training loss: 6.7230 Explore P: 0.1832
# Episode: 133 Total reward: 95.0 Training loss: 8.0480 Explore P: 0.1759
# Episode: 134 Total reward: 94.0 Training loss: 21.1608 Explore P: 0.1753
# Episode: 135 Total reward: 20.0 Training loss: 5.5611 Explore P: 0.1699
# Model Saved
# Episode: 136 Total reward: 95.0 Training loss: 14.4185 Explore P: 0.1694
# Episode: 137 Total reward: 31.0 Training loss: 3.9729 Explore P: 0.1651
# Episode: 138 Total reward: 95.0 Training loss: 8.0744 Explore P: 0.1647
# Episode: 139 Total reward: 76.0 Training loss: 7.0875 Explore P: 0.1631
# Episode: 140 Total reward: 95.0 Training loss: 7.4049 Explore P: 0.1627
# Model Saved
# Episode: 141 Total reward: 95.0 Training loss: 8.7452 Explore P: 0.1622
# Episode: 142 Total reward: 95.0 Training loss: 7.6309 Explore P: 0.1617
# Episode: 143 Total reward: 95.0 Training loss: 6.8170 Explore P: 0.1613
# Episode: 144 Total reward: 95.0 Training loss: 10.1371 Explore P: 0.1608
# Episode: 145 Total reward: 93.0 Training loss: 4.7775 Explore P: 0.1602
# Model Saved
# Episode: 146 Total reward: 12.0 Training loss: 7.3977 Explore P: 0.1548
# Episode: 147 Total reward: 49.0 Training loss: 6.0105 Explore P: 0.1518
# Episode: 148 Total reward: 40.0 Training loss: 5.2841 Explore P: 0.1482
# Episode: 149 Total reward: 16.0 Training loss: 5.6742 Explore P: 0.1434
# Episode: 150 Total reward: 70.0 Training loss: 2.8980 Explore P: 0.1417
# Model Saved
# Episode: 151 Total reward: 71.0 Training loss: 31.0464 Explore P: 0.1401
# Episode: 152 Total reward: 25.0 Training loss: 4.9895 Explore P: 0.1362
# Episode: 153 Total reward: 95.0 Training loss: 9.7886 Explore P: 0.1358
# Episode: 154 Total reward: 75.0 Training loss: 3.7770 Explore P: 0.1345
# Episode: 155 Total reward: 52.0 Training loss: 5.6714 Explore P: 0.1321
# Model Saved
# Episode: 156 Total reward: 56.0 Training loss: 7.9231 Explore P: 0.1300
# Episode: 157 Total reward: 40.0 Training loss: 6.9949 Explore P: 0.1269
# Episode: 158 Total reward: 94.0 Training loss: 11.3807 Explore P: 0.1265
# Episode: 159 Total reward: 95.0 Training loss: 5.1547 Explore P: 0.1262
# Episode: 160 Total reward: 50.0 Training loss: 9.2175 Explore P: 0.1238
# Model Saved
# Episode: 161 Total reward: 95.0 Training loss: 4.6401 Explore P: 0.1235
# Episode: 162 Total reward: 94.0 Training loss: 7.7954 Explore P: 0.1231
# Episode: 163 Total reward: 95.0 Training loss: 8.6948 Explore P: 0.1228
# Episode: 164 Total reward: 95.0 Training loss: 10.5236 Explore P: 0.1224
# Episode: 165 Total reward: 29.0 Training loss: 4.6319 Explore P: 0.1193
# Model Saved
# Episode: 166 Total reward: 51.0 Training loss: 6.5089 Explore P: 0.1171
# Episode: 167 Total reward: 95.0 Training loss: 7.6052 Explore P: 0.1168
# Episode: 168 Total reward: 95.0 Training loss: 5.7306 Explore P: 0.1165
# Episode: 169 Total reward: 58.0 Training loss: 5.3681 Explore P: 0.1144
# Episode: 170 Total reward: 91.0 Training loss: 3.9353 Explore P: 0.1139
# Model Saved
# Episode: 171 Total reward: 94.0 Training loss: 7.5627 Explore P: 0.1136
# Episode: 172 Total reward: 95.0 Training loss: 6.1077 Explore P: 0.1133
# Episode: 173 Total reward: 95.0 Training loss: 5.5703 Explore P: 0.1129
# Episode: 174 Total reward: 52.0 Training loss: 2.6871 Explore P: 0.1110
# Episode: 175 Total reward: 95.0 Training loss: 4.6907 Explore P: 0.1107
# Model Saved
# Episode: 177 Total reward: 20.0 Training loss: 6.3262 Explore P: 0.1036
# Episode: 178 Total reward: 95.0 Training loss: 6.1586 Explore P: 0.1033
# Episode: 179 Total reward: 70.0 Training loss: 5.3242 Explore P: 0.1021
# Episode: 180 Total reward: 94.0 Training loss: 6.3946 Explore P: 0.1018
# Model Saved
# Episode: 181 Total reward: 55.0 Training loss: 3.1157 Explore P: 0.1001
# Episode: 182 Total reward: 68.0 Training loss: 7.1595 Explore P: 0.0989
# Episode: 183 Total reward: 56.0 Training loss: 10.0639 Explore P: 0.0973
# Episode: 184 Total reward: 94.0 Training loss: 6.7826 Explore P: 0.0970
# Episode: 185 Total reward: 36.0 Training loss: 2.4094 Explore P: 0.0947
# Model Saved
# Episode: 186 Total reward: 51.0 Training loss: 3.7701 Explore P: 0.0930
# Episode: 187 Total reward: 94.0 Training loss: 6.7409 Explore P: 0.0927
# Episode: 188 Total reward: 93.0 Training loss: 6.9866 Explore P: 0.0924
# Episode: 189 Total reward: 95.0 Training loss: 5.0244 Explore P: 0.0921
# Episode: 190 Total reward: 48.0 Training loss: 4.0127 Explore P: 0.0904
# Model Saved
# Episode: 191 Total reward: 95.0 Training loss: 10.5909 Explore P: 0.0901
# Episode: 192 Total reward: 95.0 Training loss: 5.2806 Explore P: 0.0899
# Episode: 193 Total reward: 95.0 Training loss: 7.1946 Explore P: 0.0897
# Episode: 194 Total reward: 95.0 Training loss: 6.0007 Explore P: 0.0894
# Episode: 195 Total reward: 94.0 Training loss: 5.8473 Explore P: 0.0891
# Model Saved
# Episode: 197 Total reward: 93.0 Training loss: 6.6183 Explore P: 0.0857
# Episode: 198 Total reward: 94.0 Training loss: 4.5949 Explore P: 0.0855
# Episode: 199 Total reward: 93.0 Training loss: 4.4486 Explore P: 0.0852
# Episode: 200 Total reward: 95.0 Training loss: 6.1254 Explore P: 0.0849
# Model Saved
# Episode: 201 Total reward: 70.0 Training loss: 4.7817 Explore P: 0.0840
# Episode: 202 Total reward: 95.0 Training loss: 8.6971 Explore P: 0.0838
# Episode: 203 Total reward: 95.0 Training loss: 3.7442 Explore P: 0.0835
# Episode: 204 Total reward: 92.0 Training loss: 4.5755 Explore P: 0.0832
# Episode: 205 Total reward: 95.0 Training loss: 3.6741 Explore P: 0.0830
# Model Saved
# Episode: 206 Total reward: 95.0 Training loss: 5.9993 Explore P: 0.0828
# Episode: 207 Total reward: 94.0 Training loss: 8.4687 Explore P: 0.0825
# Episode: 208 Total reward: 59.0 Training loss: 5.4089 Explore P: 0.0812
# Episode: 209 Total reward: 95.0 Training loss: 6.2073 Explore P: 0.0810
# Episode: 210 Total reward: 75.0 Training loss: 3.4971 Explore P: 0.0800
# Model Saved
# Episode: 211 Total reward: 94.0 Training loss: 5.0429 Explore P: 0.0798
# Episode: 213 Total reward: 57.0 Training loss: 5.5323 Explore P: 0.0759
# Episode: 214 Total reward: 93.0 Training loss: 7.6369 Explore P: 0.0757
# Episode: 215 Total reward: 95.0 Training loss: 7.2127 Explore P: 0.0755
# Model Saved
# Episode: 216 Total reward: 94.0 Training loss: 5.7410 Explore P: 0.0752
# Episode: 217 Total reward: 94.0 Training loss: 4.9116 Explore P: 0.0750
# Episode: 218 Total reward: 95.0 Training loss: 4.8996 Explore P: 0.0748
# Episode: 219 Total reward: 95.0 Training loss: 7.9960 Explore P: 0.0746
# Episode: 220 Total reward: 94.0 Training loss: 2.9282 Explore P: 0.0744
# Model Saved
# Episode: 221 Total reward: 95.0 Training loss: 5.0891 Explore P: 0.0742
# Episode: 222 Total reward: 25.0 Training loss: 6.2967 Explore P: 0.0721
# Episode: 223 Total reward: 65.0 Training loss: 4.4938 Explore P: 0.0712
# Episode: 224 Total reward: 46.0 Training loss: 4.3388 Explore P: 0.0698
# Episode: 225 Total reward: 95.0 Training loss: 4.1488 Explore P: 0.0696
# Model Saved
# Episode: 226 Total reward: 94.0 Training loss: 6.8060 Explore P: 0.0694
# Episode: 227 Total reward: 44.0 Training loss: 5.7738 Explore P: 0.0679
# Episode: 228 Total reward: 52.0 Training loss: 8.9897 Explore P: 0.0666
# Episode: 229 Total reward: 51.0 Training loss: 4.4508 Explore P: 0.0654
# Episode: 230 Total reward: 93.0 Training loss: 5.0760 Explore P: 0.0652
# Model Saved
# Episode: 231 Total reward: 93.0 Training loss: 3.3257 Explore P: 0.0649
# Episode: 232 Total reward: 95.0 Training loss: 6.0027 Explore P: 0.0648
# Episode: 233 Total reward: 76.0 Training loss: 6.8553 Explore P: 0.0642
# Episode: 234 Total reward: 95.0 Training loss: 3.6453 Explore P: 0.0641
# Episode: 235 Total reward: 95.0 Training loss: 3.0329 Explore P: 0.0639
# Model Saved
# Episode: 236 Total reward: 95.0 Training loss: 3.5286 Explore P: 0.0637
# Episode: 237 Total reward: 95.0 Training loss: 4.0181 Explore P: 0.0636
# Episode: 238 Total reward: 87.0 Training loss: 7.0210 Explore P: 0.0632
# Episode: 239 Total reward: 94.0 Training loss: 3.4532 Explore P: 0.0630
# Episode: 240 Total reward: 95.0 Training loss: 5.0705 Explore P: 0.0629
# Model Saved
# Episode: 241 Total reward: 93.0 Training loss: 3.9900 Explore P: 0.0627
# Episode: 242 Total reward: 68.0 Training loss: 4.8403 Explore P: 0.0619
# Episode: 243 Total reward: 76.0 Training loss: 4.9156 Explore P: 0.0614
# Episode: 244 Total reward: 52.0 Training loss: 7.5797 Explore P: 0.0604
# Episode: 245 Total reward: 38.0 Training loss: 3.4023 Explore P: 0.0591
# Model Saved
# Episode: 246 Total reward: 55.0 Training loss: 4.4507 Explore P: 0.0582
# Episode: 247 Total reward: 95.0 Training loss: 3.2248 Explore P: 0.0581
# Episode: 248 Total reward: 95.0 Training loss: 4.0561 Explore P: 0.0579
# Episode: 249 Total reward: 95.0 Training loss: 6.5151 Explore P: 0.0578
# Episode: 250 Total reward: 68.0 Training loss: 5.2753 Explore P: 0.0571
# Model Saved
# Episode: 251 Total reward: 95.0 Training loss: 4.6440 Explore P: 0.0570
# Episode: 252 Total reward: 95.0 Training loss: 5.8390 Explore P: 0.0568
# Episode: 253 Total reward: 95.0 Training loss: 3.5233 Explore P: 0.0567
# Episode: 254 Total reward: 59.0 Training loss: 2.7791 Explore P: 0.0558
# Episode: 255 Total reward: 95.0 Training loss: 4.4167 Explore P: 0.0557
# Model Saved
# Episode: 256 Total reward: 86.0 Training loss: 4.0909 Explore P: 0.0554
# Episode: 257 Total reward: 95.0 Training loss: 4.0403 Explore P: 0.0552
# Episode: 258 Total reward: 95.0 Training loss: 4.1627 Explore P: 0.0551
# Episode: 259 Total reward: 95.0 Training loss: 4.9315 Explore P: 0.0550
# Episode: 260 Total reward: 95.0 Training loss: 3.8292 Explore P: 0.0548
# Model Saved
# Episode: 261 Total reward: 95.0 Training loss: 3.9860 Explore P: 0.0547
# Episode: 262 Total reward: 79.0 Training loss: 9.6517 Explore P: 0.0542
# Episode: 263 Total reward: 40.0 Training loss: 5.9654 Explore P: 0.0531
# Episode: 265 Total reward: 44.0 Training loss: 7.6499 Explore P: 0.0504
# Model Saved
# Episode: 266 Total reward: 50.0 Training loss: 4.8999 Explore P: 0.0496
# Episode: 267 Total reward: 95.0 Training loss: 5.8441 Explore P: 0.0495
# Episode: 268 Total reward: 95.0 Training loss: 6.2640 Explore P: 0.0494
# Episode: 269 Total reward: 95.0 Training loss: 5.2358 Explore P: 0.0493
# Episode: 270 Total reward: 58.0 Training loss: 3.8799 Explore P: 0.0485
# Model Saved
# Episode: 271 Total reward: 95.0 Training loss: 10.0504 Explore P: 0.0484
# Episode: 272 Total reward: 81.0 Training loss: 3.2208 Explore P: 0.0480
# Episode: 273 Total reward: 95.0 Training loss: 2.9836 Explore P: 0.0479
# Episode: 274 Total reward: 94.0 Training loss: 4.4034 Explore P: 0.0478
# Episode: 275 Total reward: 95.0 Training loss: 10.8944 Explore P: 0.0477
# Model Saved
# Episode: 276 Total reward: 46.0 Training loss: 3.5412 Explore P: 0.0468
# Episode: 277 Total reward: 38.0 Training loss: 3.0078 Explore P: 0.0459
# Episode: 278 Total reward: 95.0 Training loss: 3.6564 Explore P: 0.0458
# Episode: 279 Total reward: 95.0 Training loss: 12.1442 Explore P: 0.0456
# Episode: 280 Total reward: 95.0 Training loss: 2.5139 Explore P: 0.0455
# Model Saved
# Episode: 281 Total reward: 95.0 Training loss: 3.0427 Explore P: 0.0454
# Episode: 282 Total reward: 95.0 Training loss: 55.6830 Explore P: 0.0453
# Episode: 283 Total reward: 93.0 Training loss: 3.3403 Explore P: 0.0452
# Episode: 284 Total reward: 55.0 Training loss: 3.5859 Explore P: 0.0446
# Episode: 285 Total reward: 95.0 Training loss: 2.6452 Explore P: 0.0445
# Model Saved
# Episode: 286 Total reward: 95.0 Training loss: 3.4692 Explore P: 0.0444
# Episode: 287 Total reward: 85.0 Training loss: 8.7193 Explore P: 0.0441
# Episode: 288 Total reward: 95.0 Training loss: 5.5369 Explore P: 0.0440
# Episode: 289 Total reward: 95.0 Training loss: 2.9804 Explore P: 0.0439
# Episode: 290 Total reward: 94.0 Training loss: 5.2275 Explore P: 0.0438
# Model Saved
# Episode: 291 Total reward: 69.0 Training loss: 5.7627 Explore P: 0.0432
# Episode: 292 Total reward: 95.0 Training loss: 2.6968 Explore P: 0.0431
# Episode: 293 Total reward: 95.0 Training loss: 4.3472 Explore P: 0.0430
# Episode: 294 Total reward: 95.0 Training loss: 6.8287 Explore P: 0.0429
# Episode: 295 Total reward: 95.0 Training loss: 4.7446 Explore P: 0.0428
# Model Saved
# Episode: 296 Total reward: 95.0 Training loss: 8.1728 Explore P: 0.0427
# Episode: 297 Total reward: 95.0 Training loss: 19.5517 Explore P: 0.0426
# Episode: 298 Total reward: 53.0 Training loss: 4.8073 Explore P: 0.0419
# Episode: 299 Total reward: 89.0 Training loss: 3.2842 Explore P: 0.0417
# Episode: 300 Total reward: 94.0 Training loss: 2.9462 Explore P: 0.0416
# Model Saved
# Episode: 301 Total reward: 95.0 Training loss: 3.4808 Explore P: 0.0415
# Episode: 302 Total reward: 95.0 Training loss: 3.6014 Explore P: 0.0414
# Episode: 303 Total reward: 94.0 Training loss: 4.7876 Explore P: 0.0413
# Episode: 304 Total reward: 95.0 Training loss: 5.6338 Explore P: 0.0412
# Episode: 305 Total reward: 95.0 Training loss: 6.0741 Explore P: 0.0411
# Model Saved
# Episode: 306 Total reward: 94.0 Training loss: 3.1295 Explore P: 0.0410
# Episode: 307 Total reward: 95.0 Training loss: 4.9649 Explore P: 0.0409
# Episode: 308 Total reward: 53.0 Training loss: 3.7766 Explore P: 0.0403
# Episode: 309 Total reward: 71.0 Training loss: 3.0930 Explore P: 0.0398
# Episode: 310 Total reward: 95.0 Training loss: 4.5673 Explore P: 0.0397
# Model Saved
# Episode: 311 Total reward: 94.0 Training loss: 4.1825 Explore P: 0.0396
# Episode: 312 Total reward: 94.0 Training loss: 6.1331 Explore P: 0.0395
# Episode: 313 Total reward: 55.0 Training loss: 3.2250 Explore P: 0.0389
# Episode: 314 Total reward: 48.0 Training loss: 5.4978 Explore P: 0.0383
# Episode: 315 Total reward: 95.0 Training loss: 2.1677 Explore P: 0.0382
# Model Saved
# Episode: 316 Total reward: 94.0 Training loss: 5.4757 Explore P: 0.0381
# Episode: 317 Total reward: 95.0 Training loss: 4.0463 Explore P: 0.0380
# Episode: 318 Total reward: 95.0 Training loss: 4.3171 Explore P: 0.0379
# Episode: 319 Total reward: 94.0 Training loss: 4.6192 Explore P: 0.0378
# Episode: 320 Total reward: 94.0 Training loss: 6.9859 Explore P: 0.0377
# Model Saved
# Episode: 321 Total reward: 64.0 Training loss: 7.1288 Explore P: 0.0373
# Episode: 322 Total reward: 61.0 Training loss: 3.3938 Explore P: 0.0368
# Episode: 323 Total reward: 25.0 Training loss: 5.3876 Explore P: 0.0360
# Episode: 324 Total reward: 95.0 Training loss: 4.3904 Explore P: 0.0359
# Episode: 325 Total reward: 64.0 Training loss: 5.3804 Explore P: 0.0355
# Model Saved
# Episode: 326 Total reward: 58.0 Training loss: 2.7615 Explore P: 0.0350
# Episode: 327 Total reward: 85.0 Training loss: 8.1724 Explore P: 0.0348
# Episode: 328 Total reward: 94.0 Training loss: 4.5579 Explore P: 0.0347
# Episode: 329 Total reward: 93.0 Training loss: 3.7782 Explore P: 0.0346
# Episode: 330 Total reward: 94.0 Training loss: 3.6633 Explore P: 0.0345
# Model Saved
# Episode: 331 Total reward: 76.0 Training loss: 7.2840 Explore P: 0.0342
# Episode: 332 Total reward: 95.0 Training loss: 3.4130 Explore P: 0.0342
# Episode: 333 Total reward: 66.0 Training loss: 2.4435 Explore P: 0.0338
# Episode: 334 Total reward: 95.0 Training loss: 6.4658 Explore P: 0.0337
# Episode: 335 Total reward: 52.0 Training loss: 6.4120 Explore P: 0.0332
# Model Saved
# Episode: 336 Total reward: 77.0 Training loss: 4.9548 Explore P: 0.0329
# Episode: 337 Total reward: 53.0 Training loss: 10.0202 Explore P: 0.0324
# Episode: 338 Total reward: 95.0 Training loss: 4.3053 Explore P: 0.0323
# Episode: 339 Total reward: 95.0 Training loss: 4.6968 Explore P: 0.0323
# Episode: 340 Total reward: 95.0 Training loss: 4.8013 Explore P: 0.0322
# Model Saved
# Episode: 341 Total reward: 76.0 Training loss: 7.1054 Explore P: 0.0320
# Episode: 342 Total reward: 94.0 Training loss: 5.0038 Explore P: 0.0319
# Episode: 343 Total reward: 94.0 Training loss: 4.4361 Explore P: 0.0318
# Episode: 344 Total reward: 94.0 Training loss: 4.1004 Explore P: 0.0318
# Episode: 345 Total reward: 48.0 Training loss: 11.0609 Explore P: 0.0312
# Model Saved
# Episode: 346 Total reward: 94.0 Training loss: 6.7166 Explore P: 0.0312
# Episode: 347 Total reward: 95.0 Training loss: 5.1117 Explore P: 0.0311
# Episode: 348 Total reward: 94.0 Training loss: 11.2965 Explore P: 0.0310
# Episode: 349 Total reward: 95.0 Training loss: 4.3016 Explore P: 0.0310
# Episode: 350 Total reward: 54.0 Training loss: 7.5877 Explore P: 0.0305
# Model Saved
# Episode: 351 Total reward: 95.0 Training loss: 4.4096 Explore P: 0.0304
# Episode: 352 Total reward: 32.0 Training loss: 18.0113 Explore P: 0.0298
# Episode: 353 Total reward: 93.0 Training loss: 2.9470 Explore P: 0.0297
# Episode: 354 Total reward: 95.0 Training loss: 11.2728 Explore P: 0.0296
# Episode: 355 Total reward: 86.0 Training loss: 6.4253 Explore P: 0.0295
# Model Saved
# Episode: 356 Total reward: 93.0 Training loss: 4.5024 Explore P: 0.0294
# Episode: 357 Total reward: 64.0 Training loss: 3.8098 Explore P: 0.0291
# Episode: 358 Total reward: 47.0 Training loss: 4.6827 Explore P: 0.0286
# Episode: 359 Total reward: 73.0 Training loss: 6.0500 Explore P: 0.0284
# Episode: 360 Total reward: 48.0 Training loss: 3.7287 Explore P: 0.0280
# Model Saved
# Episode: 361 Total reward: 94.0 Training loss: 3.7097 Explore P: 0.0279
# Episode: 362 Total reward: 58.0 Training loss: 7.7967 Explore P: 0.0276
# Episode: 363 Total reward: 95.0 Training loss: 6.6220 Explore P: 0.0275
# Episode: 364 Total reward: 78.0 Training loss: 6.1788 Explore P: 0.0273
# Episode: 365 Total reward: 94.0 Training loss: 4.8746 Explore P: 0.0273
# Model Saved
# Episode: 366 Total reward: 53.0 Training loss: 15.3948 Explore P: 0.0269
# Episode: 367 Total reward: 94.0 Training loss: 3.7195 Explore P: 0.0268
# Episode: 368 Total reward: 95.0 Training loss: 4.2197 Explore P: 0.0268
# Episode: 369 Total reward: 76.0 Training loss: 5.2692 Explore P: 0.0266
# Episode: 370 Total reward: 94.0 Training loss: 5.2230 Explore P: 0.0265
# Model Saved
# Episode: 371 Total reward: 95.0 Training loss: 5.7775 Explore P: 0.0265
# Episode: 372 Total reward: 94.0 Training loss: 7.5894 Explore P: 0.0264
# Episode: 373 Total reward: 30.0 Training loss: 5.0224 Explore P: 0.0259
# Episode: 374 Total reward: 95.0 Training loss: 4.9455 Explore P: 0.0259
# Episode: 375 Total reward: 95.0 Training loss: 6.6370 Explore P: 0.0258
# Model Saved
# Episode: 376 Total reward: 95.0 Training loss: 5.8268 Explore P: 0.0258
# Episode: 377 Total reward: 58.0 Training loss: 5.1068 Explore P: 0.0255
# Episode: 378 Total reward: 95.0 Training loss: 4.8041 Explore P: 0.0254
# Episode: 379 Total reward: 95.0 Training loss: 5.8139 Explore P: 0.0254
# Episode: 380 Total reward: 95.0 Training loss: 8.5734 Explore P: 0.0254
# Model Saved
# Episode: 381 Total reward: 42.0 Training loss: 3.8143 Explore P: 0.0250
# Episode: 382 Total reward: 95.0 Training loss: 3.9160 Explore P: 0.0249
# Episode: 383 Total reward: 95.0 Training loss: 4.9358 Explore P: 0.0249
# Episode: 384 Total reward: 95.0 Training loss: 36.3685 Explore P: 0.0248
# Episode: 385 Total reward: 68.0 Training loss: 5.9668 Explore P: 0.0246
# Model Saved
# Episode: 386 Total reward: 95.0 Training loss: 5.7523 Explore P: 0.0246
# Episode: 387 Total reward: 78.0 Training loss: 4.6634 Explore P: 0.0244
# Episode: 388 Total reward: 95.0 Training loss: 2.7825 Explore P: 0.0244
# Episode: 389 Total reward: 95.0 Training loss: 6.5375 Explore P: 0.0243
# Episode: 390 Total reward: 30.0 Training loss: 6.0121 Explore P: 0.0239
# Model Saved
# Episode: 391 Total reward: 95.0 Training loss: 5.8284 Explore P: 0.0239
# Episode: 392 Total reward: 95.0 Training loss: 8.8324 Explore P: 0.0238
# Episode: 393 Total reward: 58.0 Training loss: 6.0216 Explore P: 0.0236
# Episode: 394 Total reward: 54.0 Training loss: 4.8991 Explore P: 0.0233
# Episode: 395 Total reward: 94.0 Training loss: 5.8148 Explore P: 0.0232
# Model Saved
# Episode: 397 Total reward: 95.0 Training loss: 4.4140 Explore P: 0.0227
# Episode: 398 Total reward: 83.0 Training loss: 5.3065 Explore P: 0.0226
# Episode: 399 Total reward: 95.0 Training loss: 4.0479 Explore P: 0.0225
# Episode: 400 Total reward: 95.0 Training loss: 5.2536 Explore P: 0.0225
# Model Saved
# Episode: 401 Total reward: 95.0 Training loss: 3.9350 Explore P: 0.0225
# Episode: 402 Total reward: 95.0 Training loss: 6.7717 Explore P: 0.0224
# Episode: 403 Total reward: 58.0 Training loss: 5.1485 Explore P: 0.0222
# Episode: 404 Total reward: 95.0 Training loss: 2.7541 Explore P: 0.0221
# Episode: 405 Total reward: 95.0 Training loss: 4.3963 Explore P: 0.0221
# Model Saved
# Episode: 406 Total reward: 62.0 Training loss: 17.8784 Explore P: 0.0219
# Episode: 407 Total reward: 95.0 Training loss: 7.0591 Explore P: 0.0219
# Episode: 408 Total reward: 47.0 Training loss: 4.9891 Explore P: 0.0216
# Episode: 409 Total reward: 61.0 Training loss: 8.4689 Explore P: 0.0214
# Episode: 410 Total reward: 95.0 Training loss: 4.5427 Explore P: 0.0214
# Model Saved
# Episode: 411 Total reward: 95.0 Training loss: 6.8167 Explore P: 0.0213
# Episode: 412 Total reward: 94.0 Training loss: 5.8167 Explore P: 0.0213
# Episode: 413 Total reward: 95.0 Training loss: 3.9187 Explore P: 0.0213
# Episode: 414 Total reward: 76.0 Training loss: 5.2871 Explore P: 0.0212
# Episode: 415 Total reward: 79.0 Training loss: 4.5312 Explore P: 0.0210
# Model Saved
# Episode: 416 Total reward: 58.0 Training loss: 3.5806 Explore P: 0.0208
# Episode: 417 Total reward: 95.0 Training loss: 8.8880 Explore P: 0.0208
# Episode: 418 Total reward: 95.0 Training loss: 3.4690 Explore P: 0.0208
# Episode: 419 Total reward: 87.0 Training loss: 4.8735 Explore P: 0.0207
# Episode: 420 Total reward: 95.0 Training loss: 3.7987 Explore P: 0.0207
# Model Saved
# Episode: 421 Total reward: 95.0 Training loss: 4.6286 Explore P: 0.0206
# Episode: 422 Total reward: 95.0 Training loss: 4.3234 Explore P: 0.0206
# Episode: 423 Total reward: 83.0 Training loss: 3.3151 Explore P: 0.0205
# Episode: 424 Total reward: 95.0 Training loss: 5.7364 Explore P: 0.0205
# Episode: 425 Total reward: 95.0 Training loss: 3.5351 Explore P: 0.0204
# Model Saved
# Episode: 426 Total reward: 63.0 Training loss: 5.8077 Explore P: 0.0203
# Episode: 427 Total reward: 95.0 Training loss: 3.9450 Explore P: 0.0202
# Episode: 428 Total reward: 94.0 Training loss: 4.8361 Explore P: 0.0202
# Episode: 429 Total reward: 67.0 Training loss: 4.7484 Explore P: 0.0201
# Episode: 430 Total reward: 94.0 Training loss: 3.4912 Explore P: 0.0200
# Model Saved
# Episode: 431 Total reward: 95.0 Training loss: 6.7473 Explore P: 0.0200
# Episode: 432 Total reward: 83.0 Training loss: 3.7143 Explore P: 0.0199
# Episode: 433 Total reward: 95.0 Training loss: 3.7987 Explore P: 0.0199
# Episode: 434 Total reward: 95.0 Training loss: 8.6940 Explore P: 0.0198
# Episode: 435 Total reward: 75.0 Training loss: 4.5670 Explore P: 0.0197
# Model Saved
# Episode: 436 Total reward: 95.0 Training loss: 6.5288 Explore P: 0.0197
# Episode: 437 Total reward: 95.0 Training loss: 3.8826 Explore P: 0.0197
# Episode: 438 Total reward: 93.0 Training loss: 4.5675 Explore P: 0.0196
# Episode: 439 Total reward: 56.0 Training loss: 5.5515 Explore P: 0.0194
# Episode: 440 Total reward: 57.0 Training loss: 5.2599 Explore P: 0.0192
# Model Saved
# Episode: 441 Total reward: 67.0 Training loss: 2.8607 Explore P: 0.0191
# Episode: 442 Total reward: 75.0 Training loss: 3.3133 Explore P: 0.0190
# Episode: 443 Total reward: 90.0 Training loss: 5.0268 Explore P: 0.0189
# Episode: 444 Total reward: 93.0 Training loss: 4.4790 Explore P: 0.0189
# Episode: 445 Total reward: 95.0 Training loss: 5.2824 Explore P: 0.0189
# Model Saved
# Episode: 446 Total reward: 95.0 Training loss: 4.3158 Explore P: 0.0189
# Episode: 447 Total reward: 58.0 Training loss: 4.3532 Explore P: 0.0187
# Episode: 448 Total reward: 57.0 Training loss: 8.1634 Explore P: 0.0185
# Episode: 449 Total reward: 95.0 Training loss: 5.2319 Explore P: 0.0185
# Episode: 450 Total reward: 95.0 Training loss: 3.8665 Explore P: 0.0185
# Model Saved
# Episode: 451 Total reward: 94.0 Training loss: 2.7583 Explore P: 0.0185
# Episode: 452 Total reward: 95.0 Training loss: 5.7864 Explore P: 0.0184
# Episode: 453 Total reward: 95.0 Training loss: 4.1443 Explore P: 0.0184
# Episode: 454 Total reward: 46.0 Training loss: 5.6936 Explore P: 0.0182
# Episode: 455 Total reward: 94.0 Training loss: 4.2723 Explore P: 0.0182
# Model Saved
# Episode: 456 Total reward: 38.0 Training loss: 3.9770 Explore P: 0.0180
# Episode: 457 Total reward: 95.0 Training loss: 3.0659 Explore P: 0.0180
# Episode: 458 Total reward: 79.0 Training loss: 4.6985 Explore P: 0.0179
# Episode: 459 Total reward: 95.0 Training loss: 4.4011 Explore P: 0.0178
# Episode: 460 Total reward: 95.0 Training loss: 2.6803 Explore P: 0.0178
# Model Saved
# Episode: 461 Total reward: 95.0 Training loss: 4.9671 Explore P: 0.0178
# Episode: 462 Total reward: 75.0 Training loss: 6.6010 Explore P: 0.0177
# Episode: 463 Total reward: 95.0 Training loss: 4.0974 Explore P: 0.0177
# Episode: 464 Total reward: 94.0 Training loss: 3.1700 Explore P: 0.0177
# Episode: 465 Total reward: 94.0 Training loss: 2.9170 Explore P: 0.0176
# Model Saved
# Episode: 466 Total reward: 95.0 Training loss: 6.4798 Explore P: 0.0176
# Episode: 467 Total reward: 77.0 Training loss: 5.2369 Explore P: 0.0175
# Episode: 468 Total reward: 75.0 Training loss: 5.5320 Explore P: 0.0174
# Episode: 469 Total reward: 95.0 Training loss: 4.6717 Explore P: 0.0174
# Episode: 470 Total reward: 95.0 Training loss: 4.0576 Explore P: 0.0174
# Model Saved
# Episode: 471 Total reward: 95.0 Training loss: 2.8044 Explore P: 0.0174
# Episode: 472 Total reward: 94.0 Training loss: 3.9839 Explore P: 0.0173
# Episode: 473 Total reward: 95.0 Training loss: 4.5214 Explore P: 0.0173
# Episode: 474 Total reward: 85.0 Training loss: 7.3539 Explore P: 0.0173
# Episode: 475 Total reward: 53.0 Training loss: 13.2347 Explore P: 0.0171
# Model Saved
# Episode: 476 Total reward: 95.0 Training loss: 5.4755 Explore P: 0.0171
# Episode: 477 Total reward: 76.0 Training loss: 3.9217 Explore P: 0.0170
# Episode: 478 Total reward: 83.0 Training loss: 4.7789 Explore P: 0.0169
# Episode: 479 Total reward: 94.0 Training loss: 8.0835 Explore P: 0.0169
# Episode: 480 Total reward: 95.0 Training loss: 5.1532 Explore P: 0.0169
# Model Saved
# Episode: 481 Total reward: 95.0 Training loss: 3.7332 Explore P: 0.0169
# Episode: 482 Total reward: 95.0 Training loss: 4.0799 Explore P: 0.0169
# Episode: 483 Total reward: 93.0 Training loss: 5.3854 Explore P: 0.0168
# Episode: 484 Total reward: 95.0 Training loss: 2.6655 Explore P: 0.0168
# Episode: 485 Total reward: 91.0 Training loss: 3.9558 Explore P: 0.0168
# Model Saved
# Episode: 486 Total reward: 95.0 Training loss: 4.0274 Explore P: 0.0168
# Episode: 487 Total reward: 95.0 Training loss: 5.4117 Explore P: 0.0167
# Episode: 488 Total reward: 76.0 Training loss: 4.4222 Explore P: 0.0167
# Episode: 489 Total reward: 95.0 Training loss: 3.9313 Explore P: 0.0167
# Episode: 490 Total reward: 94.0 Training loss: 3.8309 Explore P: 0.0166
# Model Saved
# Episode: 491 Total reward: 95.0 Training loss: 6.3272 Explore P: 0.0166
# Episode: 492 Total reward: 75.0 Training loss: 4.7813 Explore P: 0.0165
# Episode: 493 Total reward: 95.0 Training loss: 3.0285 Explore P: 0.0165
# Episode: 494 Total reward: 92.0 Training loss: 4.2767 Explore P: 0.0165
# Episode: 495 Total reward: 95.0 Training loss: 3.9339 Explore P: 0.0165
# Model Saved
# Episode: 496 Total reward: 95.0 Training loss: 3.2736 Explore P: 0.0164
# Episode: 497 Total reward: 95.0 Training loss: 2.7475 Explore P: 0.0164
# Episode: 498 Total reward: 88.0 Training loss: 5.9499 Explore P: 0.0164
# Episode: 499 Total reward: 94.0 Training loss: 3.4339 Explore P: 0.0164
# Episode: 500 Total reward: 6.0 Training loss: 5.0026 Explore P: 0.0161
# Model Saved
# Episode: 501 Total reward: 95.0 Training loss: 4.7408 Explore P: 0.0161
# Episode: 502 Total reward: 95.0 Training loss: 5.3873 Explore P: 0.0161
# Episode: 503 Total reward: 95.0 Training loss: 3.6174 Explore P: 0.0161
# Episode: 504 Total reward: 64.0 Training loss: 2.1222 Explore P: 0.0160
# Episode: 505 Total reward: 64.0 Training loss: 3.8185 Explore P: 0.0159
# Model Saved
# Episode: 506 Total reward: 83.0 Training loss: 3.6311 Explore P: 0.0158
# Episode: 507 Total reward: 71.0 Training loss: 3.6156 Explore P: 0.0157
# Episode: 508 Total reward: 95.0 Training loss: 2.3570 Explore P: 0.0157
# Episode: 509 Total reward: 85.0 Training loss: 4.6155 Explore P: 0.0157
# Episode: 510 Total reward: 93.0 Training loss: 6.4398 Explore P: 0.0156
# Model Saved
# Episode: 511 Total reward: 95.0 Training loss: 4.9881 Explore P: 0.0156
# Episode: 512 Total reward: 94.0 Training loss: 3.1015 Explore P: 0.0156
# Episode: 513 Total reward: 56.0 Training loss: 5.1622 Explore P: 0.0155
# Episode: 515 Total reward: 95.0 Training loss: 4.5053 Explore P: 0.0153
# Model Saved
# Episode: 516 Total reward: 30.0 Training loss: 4.7081 Explore P: 0.0151
# Episode: 517 Total reward: 75.0 Training loss: 11.8737 Explore P: 0.0150
# Episode: 518 Total reward: 93.0 Training loss: 4.6908 Explore P: 0.0150
# Episode: 519 Total reward: 94.0 Training loss: 3.7322 Explore P: 0.0150
# Episode: 520 Total reward: 95.0 Training loss: 8.2200 Explore P: 0.0150
# Model Saved
# Episode: 521 Total reward: 95.0 Training loss: 3.7381 Explore P: 0.0150
# Episode: 522 Total reward: 33.0 Training loss: 16.1216 Explore P: 0.0148
# Episode: 523 Total reward: 87.0 Training loss: 8.6134 Explore P: 0.0148
# Episode: 524 Total reward: 94.0 Training loss: 9.0160 Explore P: 0.0148
# Episode: 525 Total reward: 62.0 Training loss: 3.1019 Explore P: 0.0147
# Model Saved
# Episode: 526 Total reward: 95.0 Training loss: 75.5261 Explore P: 0.0147
# Episode: 527 Total reward: 32.0 Training loss: 6.4034 Explore P: 0.0145
# Episode: 528 Total reward: 52.0 Training loss: 4.5968 Explore P: 0.0144
# Episode: 529 Total reward: 95.0 Training loss: 3.0270 Explore P: 0.0144
# Episode: 530 Total reward: 61.0 Training loss: 4.4886 Explore P: 0.0144
# Model Saved
# Episode: 531 Total reward: 95.0 Training loss: 4.3606 Explore P: 0.0143
# Episode: 532 Total reward: 95.0 Training loss: 5.8635 Explore P: 0.0143
# Episode: 533 Total reward: 95.0 Training loss: 4.1648 Explore P: 0.0143
# Episode: 534 Total reward: 95.0 Training loss: 5.1502 Explore P: 0.0143
# Episode: 535 Total reward: 95.0 Training loss: 4.3556 Explore P: 0.0143
# Model Saved
# Episode: 536 Total reward: 73.0 Training loss: 11.7172 Explore P: 0.0142
# Episode: 537 Total reward: 95.0 Training loss: 3.3847 Explore P: 0.0142
# Episode: 538 Total reward: 76.0 Training loss: 7.1604 Explore P: 0.0142
# Episode: 539 Total reward: 88.0 Training loss: 7.7604 Explore P: 0.0141
# Episode: 540 Total reward: 58.0 Training loss: 3.8304 Explore P: 0.0141
# Model Saved
# Episode: 541 Total reward: 57.0 Training loss: 3.9940 Explore P: 0.0140
# Episode: 542 Total reward: 95.0 Training loss: 6.8884 Explore P: 0.0140
# Episode: 543 Total reward: 75.0 Training loss: 4.3114 Explore P: 0.0139
# Episode: 544 Total reward: 56.0 Training loss: 4.2025 Explore P: 0.0138
# Episode: 545 Total reward: 95.0 Training loss: 6.7111 Explore P: 0.0138
# Model Saved
# Episode: 546 Total reward: 95.0 Training loss: 5.1057 Explore P: 0.0138
# Episode: 547 Total reward: 95.0 Training loss: 27.3792 Explore P: 0.0138
# Episode: 548 Total reward: 57.0 Training loss: 9.4849 Explore P: 0.0137
# Episode: 549 Total reward: 95.0 Training loss: 4.3529 Explore P: 0.0137
# Episode: 550 Total reward: 74.0 Training loss: 3.2914 Explore P: 0.0137
# Model Saved
# Episode: 551 Total reward: 90.0 Training loss: 5.4960 Explore P: 0.0137
# Episode: 552 Total reward: 72.0 Training loss: 3.5009 Explore P: 0.0136
# Episode: 553 Total reward: 95.0 Training loss: 3.9984 Explore P: 0.0136
# Episode: 554 Total reward: 85.0 Training loss: 3.9811 Explore P: 0.0136
# Episode: 555 Total reward: 53.0 Training loss: 4.7323 Explore P: 0.0135
# Model Saved
# Episode: 556 Total reward: 64.0 Training loss: 3.8745 Explore P: 0.0134
# Episode: 557 Total reward: 95.0 Training loss: 2.7665 Explore P: 0.0134
# Episode: 558 Total reward: 95.0 Training loss: 5.4368 Explore P: 0.0134
# Episode: 559 Total reward: 92.0 Training loss: 4.2901 Explore P: 0.0134
# Episode: 560 Total reward: 95.0 Training loss: 4.1012 Explore P: 0.0134
# Model Saved
# Episode: 561 Total reward: 95.0 Training loss: 3.6508 Explore P: 0.0134
# Episode: 562 Total reward: 76.0 Training loss: 3.6738 Explore P: 0.0133
# Episode: 563 Total reward: 80.0 Training loss: 6.0246 Explore P: 0.0133
# Episode: 564 Total reward: 95.0 Training loss: 4.3879 Explore P: 0.0133
# Episode: 565 Total reward: 76.0 Training loss: 2.7992 Explore P: 0.0133
# Model Saved
# Episode: 566 Total reward: 66.0 Training loss: 1.9680 Explore P: 0.0132
# Episode: 567 Total reward: 95.0 Training loss: 4.4309 Explore P: 0.0132
# Episode: 568 Total reward: 95.0 Training loss: 4.9032 Explore P: 0.0132
# Episode: 569 Total reward: 95.0 Training loss: 3.0037 Explore P: 0.0132
# Episode: 570 Total reward: 95.0 Training loss: 3.3357 Explore P: 0.0132
# Model Saved
# Episode: 571 Total reward: 95.0 Training loss: 3.1631 Explore P: 0.0132
# Episode: 572 Total reward: 51.0 Training loss: 12.4632 Explore P: 0.0131
# Episode: 573 Total reward: 95.0 Training loss: 4.9516 Explore P: 0.0131
# Episode: 574 Total reward: 76.0 Training loss: 3.8143 Explore P: 0.0131
# Episode: 575 Total reward: 95.0 Training loss: 5.8039 Explore P: 0.0130
# Model Saved
# Episode: 576 Total reward: 95.0 Training loss: 3.7591 Explore P: 0.0130
# Episode: 577 Total reward: 57.0 Training loss: 4.4074 Explore P: 0.0130
# Episode: 578 Total reward: 85.0 Training loss: 6.1477 Explore P: 0.0130
# Episode: 579 Total reward: 95.0 Training loss: 5.7424 Explore P: 0.0129
# Episode: 580 Total reward: 95.0 Training loss: 6.4820 Explore P: 0.0129
# Model Saved
# Episode: 581 Total reward: 95.0 Training loss: 3.7502 Explore P: 0.0129
# Episode: 582 Total reward: 95.0 Training loss: 6.2405 Explore P: 0.0129
# Episode: 583 Total reward: 95.0 Training loss: 4.6322 Explore P: 0.0129
# Episode: 584 Total reward: 95.0 Training loss: 4.3067 Explore P: 0.0129
# Episode: 585 Total reward: 75.0 Training loss: 7.8681 Explore P: 0.0129
# Model Saved
# Episode: 586 Total reward: 83.0 Training loss: 4.6937 Explore P: 0.0128
# Episode: 587 Total reward: 76.0 Training loss: 4.3640 Explore P: 0.0128
# Episode: 588 Total reward: 95.0 Training loss: 4.1792 Explore P: 0.0128
# Episode: 589 Total reward: 95.0 Training loss: 4.6376 Explore P: 0.0128
# Episode: 590 Total reward: 87.0 Training loss: 6.9291 Explore P: 0.0128
# Model Saved
# Episode: 591 Total reward: 85.0 Training loss: 3.9180 Explore P: 0.0128
# Episode: 592 Total reward: 77.0 Training loss: 4.8120 Explore P: 0.0127
# Episode: 593 Total reward: 95.0 Training loss: 2.8774 Explore P: 0.0127
# Episode: 594 Total reward: 57.0 Training loss: 4.5262 Explore P: 0.0127
# Episode: 595 Total reward: 69.0 Training loss: 5.3217 Explore P: 0.0126
# Model Saved
# Episode: 596 Total reward: 95.0 Training loss: 4.0103 Explore P: 0.0126
# Episode: 597 Total reward: 95.0 Training loss: 6.1821 Explore P: 0.0126
# Episode: 598 Total reward: 95.0 Training loss: 3.5248 Explore P: 0.0126
# Episode: 599 Total reward: 75.0 Training loss: 5.3771 Explore P: 0.0126

# %% [markdown]
# ## Step 9: Watch our Agent play 👀
# Now that we trained our agent, we can test it

# %%
import tensorflow as tf
saver = tf.compat.v1.train.Saver()

with tf.compat.v1.Session() as sess:

    game, possible_actions = create_environment()

    totalScore = 0

    # Load the model
    saver.restore(sess, "./models/model.ckpt")
    game.init()
    for i in range(1):

        done = False

        game.new_episode()

        state = game.get_state().screen_buffer
        state, stacked_frames = stack_frames(stacked_frames, state, True)

        while not game.is_episode_finished():
            # Take the biggest Q value (= the best action)
            Qs = sess.run(DQNetwork.output, feed_dict = {DQNetwork.inputs_: state.reshape((1, *state.shape))})

            # Take the biggest Q value (= the best action)
            choice = np.argmax(Qs)
            action = possible_actions[int(choice)]

            game.make_action(action)
            done = game.is_episode_finished()
            score = game.get_total_reward()

            if done:
                break

            else:
                print("else")
                next_state = game.get_state().screen_buffer
                next_state, stacked_frames = stack_frames(stacked_frames, next_state, False)
                state = next_state

        score = game.get_total_reward()
        print("Score: ", score)
    game.close()
# Out:
# INFO:tensorflow:Restoring parameters from ./models/model.ckpt
# else
# else
# else
# else
# else
# Score:  95.0
